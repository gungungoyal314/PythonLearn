# %% [markdown]
# <a href="https://colab.research.google.com/github/gungungoyal314/PythonLearn/blob/main/mcqs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# . AWS Glue (10 MCQs)
# Q1. AWS Glue is primarily a ______ service.
#
# A) Storage
# B) ETL
# C) Compute
# D) Networking
#
# Answer: ✅ B
#
# Q2. AWS Glue is a:
#
# A) Managed Service
# B) Virtual Machine
# C) Database
# D) IDE
#
# Answer: ✅ A
#
# Q3. Glue mainly performs:
#
# A) Data Visualization
# B) ETL Operations
# C) Email Service
# D) Web Hosting
#
# Answer: ✅ B
#
# Q4. ETL stands for:
#
# A) Extract, Transform, Load
# B) Execute, Transfer, Load
# C) Extract, Test, Load
# D) Enter, Transform, Link
#
# Answer: ✅ A
#
# Q5. Which language is commonly used in AWS Glue?
#
# A) Java
# B) Python
# C) C#
# D) PHP
#
# Answer: ✅ B
#
# Q6. AWS Glue is serverless because:
#
# A) No servers exist
# B) AWS manages infrastructure
# C) User buys servers
# D) Uses EC2 always
#
# Answer: ✅ B
#
# Q7. Glue integrates easily with:
#
# A) S3
# B) Redshift
# C) Athena
# D) All of the above
#
# Answer: ✅ D
#
# Q8. AWS Glue automatically provisions:
#
# A) CPU
# B) Memory
# C) Infrastructure
# D) Database
#
# Answer: ✅ C
#
# Q9. AWS Glue pricing depends on:
#
# A) Storage only
# B) DPU usage
# C) Number of users
# D) IAM roles
#
# Answer: ✅ B
#
# Q10. Which AWS service is mainly used for ETL?
#
# A) Lambda
# B) Athena
# C) Glue
# D) EC2
#
# Answer: ✅ C
#
# 2. AWS Glue Crawler (10 MCQs)
# Q1. Glue Crawler is used to:
#
# A) Upload files
# B) Scan data source
# C) Delete data
# D) Encrypt data
#
# ✅ Answer: B
#
# Q2. Glue Crawler automatically creates:
#
# A) EC2
# B) Tables
# C) IAM
# D) Lambda
#
# ✅ Answer: B
#
# Q3. Glue Crawler stores metadata in:
#
# A) Athena
# B) Data Catalog
# C) S3
# D) Lambda
#
# ✅ Answer: B
#
# Q4. Glue Crawler can crawl:
#
# A) S3
# B) JDBC
# C) DynamoDB
# D) All of these
#
# ✅ Answer: D
#
# Q5. Glue Crawler identifies:
#
# A) Schema
# B) Password
# C) IAM Policy
# D) EC2 Type
#
# ✅ Answer: A
#
# Q6. Crawler reads:
#
# A) Metadata
# B) Video
# C) Password
# D) HTML
#
# ✅ Answer: A
#
# Q7. Glue Crawler updates:
#
# A) Security Groups
# B) Data Catalog
# C) IAM Users
# D) Lambda
#
# ✅ Answer: B
#
# Q8. Which format can Crawler detect?
#
# A) CSV
# B) JSON
# C) Parquet
# D) All
#
# ✅ Answer: D
#
# Q9. Crawler supports scheduling?
#
# A) Yes
# B) No
#
# ✅ Answer: A
#
# Q10. Glue Crawler creates:
#
# A) Metadata only
# B) Actual data
# C) Buckets
# D) EC2
#
# ✅ Answer: A
#
# 3. AWS Glue Data Catalog (10 MCQs)
# Q1. Data Catalog stores:
#
# A) Metadata
# B) Images
# C) EC2
# D) IAM
#
# ✅ Answer: A
#
# Q2. Data Catalog acts as:
#
# A) Metadata Repository
# B) Storage Service
# C) Database Server
# D) Cache
#
# ✅ Answer: A
#
# Q3. Athena uses:
#
# A) IAM
# B) Data Catalog
# C) EC2
# D) Lambda
#
# ✅ Answer: B
#
# Q4. Data Catalog contains:
#
# A) Tables
# B) Databases
# C) Schema
# D) All
#
# ✅ Answer: D
#
# Q5. Data Catalog is mainly used by:
#
# A) Glue
# B) Athena
# C) Redshift Spectrum
# D) All
#
# ✅ Answer: D
#
# Q6. Metadata means:
#
# A) Data about Data
# B) Backup
# C) Password
# D) Logs
#
# ✅ Answer: A
#
# Q7. Data Catalog stores actual files?
#
# A) Yes
# B) No
#
# ✅ Answer: B
#
# Q8. Which service updates Data Catalog?
#
# A) Crawler
# B) Lambda
# C) IAM
# D) SNS
#
# ✅ Answer: A
#
# Q9. Data Catalog improves:
#
# A) Querying
# B) Data Discovery
# C) Governance
# D) All
#
# ✅ Answer: D
#
# Q10. Metadata includes:
#
# A) Column names
# B) Data types
# C) Table names
# D) All
#
# ✅ Answer: D
#
# 4. AWS Glue Job (10 MCQs)
# Q1. Glue Job performs:
#
# A) ETL
# B) Networking
# C) Hosting
# D) Storage
#
# ✅ Answer: A
#
# Q2. Glue Job runs on:
#
# A) Spark
# B) MySQL
# C) Apache
# D) Nginx
#
# ✅ Answer: A
#
# Q3. Glue Job language:
#
# A) Python
# B) Scala
# C) Both
# D) JavaScript
#
# ✅ Answer: C
#
# Q4. Glue Job reads data from:
#
# A) S3
# B) JDBC
# C) Data Catalog
# D) All
#
# ✅ Answer: D
#
# Q5. Glue Job writes output to:
#
# A) S3
# B) Redshift
# C) RDS
# D) All
#
# ✅ Answer: D
#
# Q6. Glue Job is:
#
# A) Manual only
# B) Scheduled
# C) Cannot automate
# D) Static
#
# ✅ Answer: B
#
# Q7. Glue Job can transform:
#
# A) CSV
# B) JSON
# C) Parquet
# D) All
#
# ✅ Answer: D
#
# Q8. Glue Job logs are available in:
#
# A) CloudWatch
# B) IAM
# C) SNS
# D) Route53
#
# ✅ Answer: A
#
# Q9. Glue Job requires:
#
# A) IAM Role
# B) EC2
# C) VPN
# D) Route53
#
# ✅ Answer: A
#
# Q10. Glue Job automatically scales?
#
# A) Yes
# B) No
#
# ✅ Answer: A
#
# 5. AWS Athena (10 MCQs)
# Q1. Athena is used for:
#
# A) SQL Queries
# B) Storage
# C) Email
# D) Compute
#
# ✅ Answer: A
#
# Q2. Athena queries data stored in:
#
# A) S3
# B) EC2
# C) Lambda
# D) SNS
#
# ✅ Answer: A
#
# Q3. Athena uses:
#
# A) SQL
# B) Java
# C) Python
# D) PHP
#
# ✅ Answer: A
#
# Q4. Athena is:
#
# A) Serverless
# B) Managed VM
# C) Database
# D) IDE
#
# ✅ Answer: A
#
# Q5. Athena requires:
#
# A) Data Catalog
# B) IAM only
# C) EC2
# D) VPC
#
# ✅ Answer: A
#
# Q6. Athena charges based on:
#
# A) Queryed Data Scanned
# B) Storage
# C) Users
# D) IAM
#
# ✅ Answer: A
#
# Q7. Athena supports:
#
# A) CSV
# B) JSON
# C) Parquet
# D) All
#
# ✅ Answer: D
#
# Q8. Athena doesn't store data.
#
# A) True
# B) False
#
# ✅ Answer: A
#
# Q9. Athena is ideal for:
#
# A) Ad-hoc Queries
# B) Gaming
# C) Networking
# D) Web Hosting
#
# ✅ Answer: A
#
# Q10. Athena results are stored in:
#
# A) S3
# B) EC2
# C) Lambda
# D) IAM
#
# ✅ Answer: A
#
# 6. AWS Athena Workgroup (10 MCQs)
# Q1. Workgroup is used to:
#
# A) Organize Queries
# B) Store Files
# C) Launch EC2
# D) Create IAM
#
# ✅ Answer: A
#
# Q2. Athena Workgroup controls:
#
# A) Query Cost
# B) Permissions
# C) Query Settings
# D) All
#
# ✅ Answer: D
#
# Q3. Different teams can use:
#
# A) Different Workgroups
# B) Same Bucket
# C) Same IAM only
# D) None
#
# ✅ Answer: A
#
# Q4. Workgroup can define:
#
# A) Output Location
# B) Query Limit
# C) Encryption
# D) All
#
# ✅ Answer: D
#
# Q5. Athena Workgroup helps in:
#
# A) Cost Management
# B) Networking
# C) Backup
# D) EC2 Launch
#
# ✅ Answer: A
#
# Q6. Query results are saved based on:
#
# A) Workgroup settings
# B) EC2
# C) IAM
# D) Lambda
#
# ✅ Answer: A
#
# Q7. Multiple Workgroups can exist?
#
# A) Yes
# B) No
#
# ✅ Answer: A
#
# Q8. Workgroup supports CloudWatch metrics.
#
# A) True
# B) False
#
# ✅ Answer: A
#
# Q9. Workgroup belongs to:
#
# A) Athena
# B) S3
# C) IAM
# D) Lambda
#
# ✅ Answer: A
#
# Q10. Default Workgroup name is:
#
# A) primary
# B) default
# C) root
# D) admin
#
# ✅ Answer: A
