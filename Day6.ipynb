# %% [markdown]
# <a href="https://colab.research.google.com/github/gungungoyal314/PythonLearn/blob/main/Day6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# inheritence in python
class Animal:
    def sound(self):
        print("Animals make sounds")

class Dog(Animal):
    def bark(self):
        print("Dog barks")

class Cat(Animal):
  def meow(self):
    print("Cat Meows")

d = Dog()
c = Cat()
c.meow()
d.sound()   # Parent class method
d.bark()    # Child class method
# Out:
# Cat Meows
# Animals make sounds
# Dog barks

# %%
class Grandparent:
  def show(self):
    print("Grandparent")


class Parent(Grandparent):
  def show1(self):
    print("Parent")


class Child(Parent):
  def show2(Self):
    print("Child")


c = Child()
c.show()
c.show1()
c.show2()
# Out:
# Grandparent
# Parent
# Child

# %%
class Car:
  def model(self):
    print("BMW")


class BMW(Car):
  def show1(self):
    print("AUDI")

c = Car()
c.model()
b = BMW()
b.show1()
# Out:
# BMW
# AUDI

# %%
# in class we make functions called methods

# %%
class User1:
  def __init__(self , pen , pencil):
    print("constructor od user 1")
    self.pen = pen
    self.pencil = pencil
  def penGet(self):
    print("This is a pen : ", self.pen)
  def pencilGet(self):
    print("This is a pencil :", self.pencil)



class User2 (User1):
  def __init__(self , pen ,  pencil ,  eraser):
    print("constructor of user 2")

    #self.pen = pen
    #self.pencil = pencil
    super().__init__(pen,pencil)
    self.eraser  = eraser



u = User2("blue","black","This is a eraser : white")
u.penGet()
u.pencilGet()
print(u.eraser)
# Out:
# constructor of user 2
# constructor od user 1
# This is a pen :  blue
# This is a pencil : black
# This is a eraser : white

# %%
class Abhishek:
  def __init__(self , bike):
    self.bike = bike
  def useBike(self):
    print("Bike used  : ",self.bike)


class gungun(Abhishek):
  def __init__(self , name ,bike):
    #self.name = name
    #self.bike = bike
    super().__init__(bike)
    self.name = name

  def use_Name(self):
    print("Name is : " ,self.name)


u = gungun(" Abhishek", "Royal Enfield")
useName = u.use_Name()
useBike = u.useBike()
# Out:
# Name is :   Abhishek
# Bike used  :  Royal Enfield

# %%
# Encapsulation
class Student:
  def __init__(self , name , roll_no):
    self.__data=  name  # name is attribute
    self.roll_no  = roll_no  # roll_no  is attribute
  def get_name(self, password = None):
    if password == "123456":
      print(self.__data)
    else:
      print("Password not match")


s = Student("gungun" , 1234)
print(s.roll_no)
s.get_name("12345")
# Out:
# 1234
# Password not match

# %%
# Encapsulation
class Student:
  def __init__(self , name , roll_no):
    self.__data=  name  # name is attribute
    self.roll_no  = roll_no  # roll_no  is attribute
  def get_name(self, password = None):
    if password == "123456":
      print(self.__data)
    else:
      print("Password not match")


s = Student("gungun" , 1234)
print(s.roll_no)
s.get_name("123456")
# Out:
# 1234
# gungun

# %%
class BankAccount:
    def __init__(self, balance):
        self.__balance = balance   # Private variable

    def deposit(self, amount):
        self.__balance += amount
        print(f"₹{amount} deposited")

    def withdraw(self, amount):
        if amount <= self.__balance:
            self.__balance -= amount
            print(f"₹{amount} withdrawn")
        else:
            print("Insufficient Balance")

    def get_balance(self):
        return self.__balance


# Object Creation
acc = BankAccount(1000)

acc.deposit(500)
acc.withdraw(200)

print("Current Balance:", acc.get_balance())

# %%
# class variable
class Student:
  count = 0
  def __init__(self , name , roll_no):
    print("constructor is working")
    self.name = name
    self.roll_no = roll_no
    Student.count += 1
  def getname(self):
    print(self.getname)


s =Student("gungun", 23)
s.getname()


s1 = Student("abhii", 5)
s1.getname()
print(s.count)
# Out:
# constructor is working
# <bound method Student.getname of <__main__.Student object at 0x7dd619c7b260>>
# constructor is working
# <bound method Student.getname of <__main__.Student object at 0x7dd619c7a060>>
# 2

# %%
#class variable
class Student:
  count = 0
  def __init__(self,name,rlno):
    print("Constructor is working")
    self.name = name
    self.rlno = rlno
    Student.count += 12

  def getname(self):
    print(self.name)

s = Student("Abhishek",123)
s.getname()

s1 = Student("Gungun",456)
s1.getname()
print(s.count)
# Out:
# Constructor is working
# Abhishek
# Constructor is working
# Gungun
# 24

# %%
class User:
  name = " "
  roll_no = ""
  def __init__(self,name,roll_no):
    User.name = name
    User.roll_no   = roll_no
  def getname(self):
    pass # Added pass to resolve IndentationError
u = User("gungun",123)
u.getname()
print(u.name) # Changed u.name() to print(u.name) to access the attribute
# Out:
# gungun

# %%
# overriding vs overloading

def Student123(name ,roll_no):
  print(name,roll_no)


def Student123(name ,roll_no,age):
    print(name,roll_no,age)


Student123("gungun", 123,20)
# Out:
# gungun 123 20
