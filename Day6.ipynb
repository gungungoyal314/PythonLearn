# %% [markdown]
# <a href="https://colab.research.google.com/github/gungungoyal314/PythonLearn/blob/main/Day6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# when we call method we use parentheses ()
# when we direct call these . is used

# %%
# file handling
# read
# update
# append
print("h")
# Out:
# h

# %%
from google.colab import drive
#drive.mount('/content/drive')

data = open("/content/drive/MyDrive/hello .txt")
data.read()
# Out:
# 'hello file handling'

# %%
from google.colab import drive


data1 = open('/content/drive/MyDrive/hello .txt', 'w')
data1.write('Hello from Colab!\n')
data1.close()

# %%
data1 = open('/content/drive/MyDrive/hello .txt', 'r')
data1.read()
# Out:
# ''

# %%
from google.colab import drive
#drive.mount('/content/drive')

data = open("/content/drive/MyDrive/file1.csv")
data.read()
# Out:
# 'name,roll no\ndheeraj,123\nkunal,1234\nabhishek,12345\npraveen,12356\nanjali,1234567'

# %%
# write and read
data2 = open("/content/drive/MyDrive/hello.txt","w")
data2.write("we are indians")

data2 = open("/content/drive/MyDrive/hello.txt","r")
data2.read()
# Out:
# 'we are indians'
