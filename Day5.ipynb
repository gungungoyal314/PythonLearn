# %% [markdown]
# <a href="https://colab.research.google.com/github/gungungoyal314/PythonLearn/blob/main/Day5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# OOPS IN PYTHON
class Student:
  name = "nikhil"
  roll_no = 123

s = Student()   # object
print(s.name)   # attribute
# print(s.roll_no)
# Out:
# nikhil

# %%
class Student:
  def __init__(s,name,roll_no):   # constructor
    s.name = name
    s.roll_no = roll_no



s = Student("gungun", 123)
print(s.name)
print(s.roll_no)

# self is not compulsary we can use any of the word instead of this
# Out:
# gungun
# 123

# %%
class Student:
  def __init__(self,name,roll_no,age):
    self.name = name
    self.roll_no = roll_no
    self.age = age

s = Student("gungun",23,21)
print(s.name)
print(s.roll_no)
print(s.age)
# Out:
# gungun
# 23
# 21

# %%
class Student:
  def __init__(this,name,roll_no,age):
    this.name = name
    this.roll_no = roll_no
    this.age = age

#s = Student("gungun",20,20)
#print(s.name , s.roll_no , s.age)

s = Student(roll_no= 123 , name = "baby", age = 21)
print(s.name , s.roll_no , s.age)
# Out:
# baby 123 21

# %%
class Student:
  def __init__(this , name ,  roll_no , age = None):
    this.name = name
    this.roll_no = roll_no
    this.age = age
s = Student("gungun" , 123)
print(s.name , s.roll_no , s.age)

s1 = Student("baby" , 123 , 21)
print(s1.name , s1.roll_no , s1.age)
# Out:
# gungun 123 None
# baby 123 21

# %%
class Student:
  def __init__(this , *args):  # type  --> tuple \ immutable
   print(type(args))  # tuple
   print(args)
   this.data = args

s = Student("gungun", 123 , 20)

print(s.data[0],s.data[1],s.data[2])
# Out:
# <class 'tuple'>
# ('gungun', 123, 20)
# gungun 123 20

# %%
class Student:
  def __init__(self , *args):
    self.data = args
s = Student(["gungun", 'abhii', 'kushu'])
print(s.data[0][0])
# Out:
# gungun

# %%
# example
class Student:
  def __init__(self,*args):
    self.data = args


s = Student({"users":["nikhil","raj","abhishek","vineet"]},{"adderess":{"home-town":"kukas","office":"jaipur"}})

for i in s.data[0]["users"]:
    print(i)
print(s.data[1]["adderess"]["home-town"])
print(s.data[1]["adderess"]["office"])
# Out:
# nikhil
# raj
# abhishek
# vineet
# kukas
# jaipur

# %%
class Student:
  def __init__(self , name , roll_no ):
    self.name = name
    self.roll_no = roll_no

  # get
  def getName(self):
    print(self.name)
  # update
  def updateName(self):
    self.name  = "hello"
    print(self.name)
  # delete
  def DeleteName(self):
    del self.name
    #print(self.name)

  # create
  def createName(self):
    self.name = "gungun goyal"
    print(self.name)

s  = Student("gungun"  , 123)
s.getName()
s.updateName()
s.DeleteName()
s.createName()
# Out:
# gungun
# hello
# gungun goyal

# %%
class Student:
  def __init__(self,name,roll_no):
    print("auto start")
    self.name = name
    self.roll_no = roll_no
  # get
  def updateName(self,name=None): # default value -> none
    if name != None:
      self.name = name
    print(self.name)


inst = Student("nikhil",123)
inst.updateName("rajendra")

inst1 = Student("abhishek",321)
inst1.updateName()
# Out:
# auto start
# rajendra
# auto start
# abhishek

# %%
# Inheritence
class Student:
  def __init__(self,name,roll_no):
    self.name = name
    self.roll_no = roll_no
  def getData(self):
    print(self.name , self.roll_no)



class Address (Student):
  def __init__(self,   name,  roll_no  , city , state ):
    self.city = city
    self.state = state
    super().__init__(name , roll_no )
    def getAddress(self):
      print(self.city,self.state)



a = Address ("nikhil" , 123 , "jaipur" , "rajasthan")
s.getData()
# Out:
# nikhil 123
