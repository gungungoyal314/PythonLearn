# %% [markdown]
# <a href="https://colab.research.google.com/github/gungungoyal314/PythonLearn/blob/main/Day4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# list methods
# 1. append
lis = [10,20,30]
lis.append(40)
print(lis)
# Out:
# [10, 20, 30, 40]

# %%
# 2. insert
lis = [10,20,30]
lis.insert(2,40)
print(lis)
# Out:
# [10, 20, 40, 30]

# %%
# 3. len()
lis =  [10,20,30]
print(len(lis))
# Out:
# 3

# %%
# list element accessing by using indexing
lis = [10,20,30]
lis[2]
# Out:
# 30

# %%
# loop statement
# for loop
# while loop
lis = [10,20,30]
for i in lis:
    print(i)
# Out:
# 10
# 20
# 30

# %%
# while loop
lis = [10,20,30]
i = 0
while i<len(lis):
    print(lis[i])
    i+=1
# Out:
# 10
# 20
# 30

# %%
lis = [10,20,30]
for i in range(len(lis)):
 print(lis[0])
# Out:
# 10
# 10
# 10

# %%
l = [10,20,30]
len(l)
# Out:
# 3

# %%
for i in range(3):
  print(i)
# Out:
# 0
# 1
# 2

# %%
d = {"users" : ["Nikhil" , "Raj"]}
for d in range(2):
  print(d)
# Out:
# 0
# 1

# %%
for i in range(2):
  print(d)
# Out:
# {'users': ['Nikhil', 'Raj']}
# {'users': ['Nikhil', 'Raj']}

# %%
for i in range (2):
  print(d["users"])
# Out:
# ['Nikhil', 'Raj']
# ['Nikhil', 'Raj']

# %%
d = {"users" : ["Nikhil" , "Raj"]}
for i in range(2):
  print(d["users"][i])
# Out:
# Nikhil
# Raj

# %%
for i in range (len(d["users"])):
 print(d["users"][i])
# Out:
# Nikhil
# Raj

# %%
for i in d["users"]:
  print(i)
# Out:
# Nikhil
# Raj

# %%
d = { "name" : "Gungun", "age": 20 , " roll" : 23}
d.keys()
for i in range (3):
  print(i)
# Out:
# 0
# 1
# 2

# %%
for i in range(3):
  print(d.keys())
# Out:
# dict_keys(['name', 'age', ' roll'])
# dict_keys(['name', 'age', ' roll'])
# dict_keys(['name', 'age', ' roll'])

# %%
for i in range(1):
  print(d['name'])
  print(d['age'])
  print(d[' roll'])
# Out:
# Gungun
# 20
# 23

# %%
# while loop
# homework

# %%
# Functions
def hello():
  print("hello function")

# %%
def name(a):
  print(a)
name("gungun")
# Out:
# gungun

# %%
def name (a,b):
  print(a,b)
name("abhiii" , "gungun")
# Out:
# abhiii gungun

# %%
def name(*a):
  for i in a:
    print(i)
  print(a)
name("abhiii" , "gungun")
name('a','b','c','d','e')
name("hello")
# Out:
# abhiii
# gungun
# ('abhiii', 'gungun')
# a
# b
# c
# d
# e
# ('a', 'b', 'c', 'd', 'e')
# hello
# ('hello',)

# %%
def name(*a):
  for i in a:
    print(i)

name('nikhil','raj')
name('a','b','c','d','e')
name('hello')
# Out:
# nikhil
# raj
# a
# b
# c
# d
# e
# hello
