# %% [markdown]
# <a href="https://colab.research.google.com/github/gungungoyal314/PythonLearn/blob/main/dsa_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = 20
def result():
 for i in range (1 , num+1):
  if num % i == 0:
    print("factor")
  result.append(i)
 return result()
